# %%
#Cargar la biblioteca pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#Importante para la actividad
import seaborn as sns
import scipy.stats as st
import math

# %%
pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

# %%
df = pd.read_csv('master.csv')

# %%
df
# Out:
#           country  year     sex          age  suicides_no  population  \
# 0         Albania  1987    male  15-24 years           21      312900
# 1         Albania  1987    male  35-54 years           16      308000
# 2         Albania  1987  female  15-24 years           14      289700
# 3         Albania  1987    male    75+ years            1       21800
# 4         Albania  1987    male  25-34 years            9      274300
# 5         Albania  1987  female    75+ years            1       35600
# 6         Albania  1987  female  35-54 years            6      278800
# 7         Albania  1987  female  25-34 years            4      257200
# 8         Albania  1987    male  55-74 years            1      137500
# 9         Albania  1987  female   5-14 years            0      311000
# 10        Albania  1987  female  55-74 years            0      144600
# 11        Albania  1987    male   5-14 years            0      338200
# ...

# %%
dfmexico = df[df["country"] == "Mexico"]

# %%
dfhombres = pd.DataFrame()
aux = []
for i in range(1985,2016):
    aux.append(i)
dfhombres["Año"] = aux
for j in range(1985,2016):
    dfhombresaux = []
    for i in range(1985,2016):
#x1: suicidios de mujeres en mexico 2015
#x2: suicidios de hombres en mexico 2015
#n1: poblacion de mujeres
#n2: población de hombres
        df2015 = dfmexico[dfmexico["year"] == j]
        dfauxh = dfmexico[dfmexico["year"] == i]
        df2015h = df2015[df2015["sex"] == "male"]
        dfauxh = dfauxh[dfauxh["sex"] == "male"]
        n1 = sum(df2015h["population"])
        n2 = sum(dfauxh["population"])
        x1 = sum(df2015h["suicides_no"])
        x2 = sum(dfauxh["suicides_no"])
        p1 = x1/n1
        p2 = x2/n2
#Prubeba de proporciones
#Estadisitoc de pruba
        p = (x1 + x2)/(n1 + n2)
#Z calculada
        z = (p1 - p2)/((p*(1 - p)*(1/n1 + 1/n2)))**.5
#La z alpa = 0.5
        if z>st.norm.ppf(.975):
            dfhombresaux.append(np.NaN)
        elif z<-st.norm.ppf(.975):
            dfhombresaux.append(np.NaN)
        else:
            dfhombresaux.append(j)
    dfhombres[j] = dfhombresaux

# %%
dfmujeres = pd.DataFrame()
aux = []
for i in range(1985,2016):
    aux.append(i)
dfmujeres["Año"] = aux
for j in range(1985,2016):
    dfmujeresaux = []
    for i in range(1985,2016):
#x1: suicidios de mujeres en mexico 2015
#x2: suicidios de hombres en mexico 2015
#n1: poblacion de mujeres
#n2: población de hombres
        df2015 = dfmexico[dfmexico["year"] == j]
        dfauxm = dfmexico[dfmexico["year"] == i]
        df2015m= df2015[df2015["sex"] == "female"]
        dfauxm = dfauxm[dfauxm["sex"] == "female"]
        n1 = sum(df2015m["population"])
        n2 = sum(dfauxm["population"])
        x1 = sum(df2015m["suicides_no"])
        x2 = sum(dfauxm["suicides_no"])
        p1 = x1/n1
        p2 = x2/n2
#Prubeba de proporciones
#Estadisitoc de pruba
        p = (x1 + x2)/(n1 + n2)
#Z calculada
        z = (p1 - p2)/((p*(1 - p)*(1/n1 + 1/n2)))**.5
#La z alpa = 0.5
        if z>st.norm.ppf(.975):
            dfmujeresaux.append(np.NaN)
        elif z<-st.norm.ppf(.975):
            dfmujeresaux.append(np.NaN)
        else:
            dfmujeresaux.append(j)
    dfmujeres[j] = dfmujeresaux

# %%
sns.set(rc={'figure.figsize':(14,10.27)})
dfmujeres.plot(x="Año", y=[1985,1986,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015], marker= ".", linestyle="none")
plt.xlabel("Año")
plt.ylabel("Año")
plt.show()

# %%
sns.set(rc={'figure.figsize':(14,10.27)})
dfhombres.plot(x="Año", y=[1985,1986,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015], marker= ".", linestyle="none")
plt.xlabel("Año")
plt.ylabel("Año")
plt.show()

# %%
dfpaises = pd.DataFrame()
aux = []
for i in range(1985,2016):
    aux.append(i)
dfpaises["Año"] = aux
dfusa = df[df["country"] == "United States"]
dfpaisesaux = []
for i in range(1985,2016):
#x1: suicidios de mujeres en mexico 2015
#x2: suicidios de hombres en mexico 2015
#n1: poblacion de mujeres
#n2: población de hombres
    dfaño = dfmexico[dfmexico["year"] == i]
    dfaux = dfusa[dfusa["year"] == i]
#    dfaño= dfaño[dfaño["sex"] == "female"]
#    dfauxm = dfauxm[dfauxm["sex"] == "female"]
    n1 = sum(dfaño["population"])
    n2 = sum(dfaux["population"])
    x1 = sum(dfaño["suicides_no"])
    x2 = sum(dfaux["suicides_no"])
    p1 = x1/n1
    p2 = x2/n2
#Prubeba de proporciones
#Estadisitoc de pruba
    p = (x1 + x2)/(n1 + n2)
#Z calculada
    z = (p1 - p2)/((p*(1 - p)*(1/n1 + 1/n2)))**.5
#La z alpa = 0.5
    if z>st.norm.ppf(.975):
        dfpaisesaux.append(np.NaN)
    elif z<-st.norm.ppf(.975):
        dfpaisesaux.append(np.NaN)
    else:
        dfpaisesaux.append(i)
dfpaises["Usa"] = dfpaisesaux

# %%
aux = []
for i in range(1985,2016):
    aux.append(i)
dfpaises["Año"] = aux
dfbrazil = df[df["country"] == "Brazil"]
dfpaisesaux = []
for i in range(1985,2016):
#x1: suicidios de mujeres en mexico 2015
#x2: suicidios de hombres en mexico 2015
#n1: poblacion de mujeres
#n2: población de hombres
    dfaño = dfmexico[dfmexico["year"] == i]
    dfaux = dfbrazil[dfbrazil["year"] == i]
#    dfaño= dfaño[dfaño["sex"] == "female"]
#    dfauxm = dfauxm[dfauxm["sex"] == "female"]
    n1 = sum(dfaño["population"])
    n2 = sum(dfaux["population"])
    x1 = sum(dfaño["suicides_no"])
    x2 = sum(dfaux["suicides_no"])
    p1 = x1/n1
    p2 = x2/n2
#Prubeba de proporciones
#Estadisitoc de pruba
    p = (x1 + x2)/(n1 + n2)
#Z calculada
    z = (p1 - p2)/((p*(1 - p)*(1/n1 + 1/n2)))**.5
#La z alpa = 0.5
    if z>st.norm.ppf(.975):
        dfpaisesaux.append(np.NaN)
    elif z<-st.norm.ppf(.975):
        dfpaisesaux.append(np.NaN)
    else:
        dfpaisesaux.append(i)
dfpaises["Brazil"] = dfpaisesaux

# %%
aux = []
for i in range(1985,2016):
    aux.append(i)
dfpaises["Año"] = aux
dfargentina = df[df["country"] == "Argentina"]
dfpaisesaux = []
for i in range(1985,2016):
#x1: suicidios de mujeres en mexico 2015
#x2: suicidios de hombres en mexico 2015
#n1: poblacion de mujeres
#n2: población de hombres
    dfaño = dfmexico[dfmexico["year"] == i]
    dfaux = dfargentina[dfargentina["year"] == i]
#    dfaño= dfaño[dfaño["sex"] == "female"]
#    dfauxm = dfauxm[dfauxm["sex"] == "female"]
    n1 = sum(dfaño["population"])
    n2 = sum(dfaux["population"])
    x1 = sum(dfaño["suicides_no"])
    x2 = sum(dfaux["suicides_no"])
    p1 = x1/n1
    p2 = x2/n2
#Prubeba de proporciones
#Estadisitoc de pruba
    p = (x1 + x2)/(n1 + n2)
#Z calculada
    z = (p1 - p2)/((p*(1 - p)*(1/n1 + 1/n2)))**.5
#La z alpa = 0.5
    if z>st.norm.ppf(.975):
        dfpaisesaux.append(np.NaN)
    elif z<-st.norm.ppf(.975):
        dfpaisesaux.append(np.NaN)
    else:
        dfpaisesaux.append(i)
dfpaises["Argentina"] = dfpaisesaux

# %%
aux = []
for i in range(1985,2016):
    aux.append(i)
dfpaises["Año"] = aux
dfchile = df[df["country"] == "Chile"]
dfpaisesaux = []
for i in range(1985,2016):
#x1: suicidios de mujeres en mexico 2015
#x2: suicidios de hombres en mexico 2015
#n1: poblacion de mujeres
#n2: población de hombres
    dfaño = dfmexico[dfmexico["year"] == i]
    dfaux = dfchile[dfchile["year"] == i]
#    dfaño= dfaño[dfaño["sex"] == "female"]
#    dfauxm = dfauxm[dfauxm["sex"] == "female"]
    n1 = sum(dfaño["population"])
    n2 = sum(dfaux["population"])
    x1 = sum(dfaño["suicides_no"])
    x2 = sum(dfaux["suicides_no"])
    p1 = x1/n1
    p2 = x2/n2
#Prubeba de proporciones
#Estadisitoc de pruba
    p = (x1 + x2)/(n1 + n2)
#Z calculada
    z = (p1 - p2)/((p*(1 - p)*(1/n1 + 1/n2)))**.5
#La z alpa = 0.5
    if z>st.norm.ppf(.975):
        dfpaisesaux.append(np.NaN)
    elif z<-st.norm.ppf(.975):
        dfpaisesaux.append(np.NaN)
    else:
        dfpaisesaux.append(i)
dfpaises["Chile"] = dfpaisesaux

# %%
aux = []
for i in range(1985,2016):
    aux.append(i)
dfpaises["Año"] = aux
dfpuerto = df[df["country"] == "Puerto Rico"]
dfpaisesaux = []
for i in range(1985,2016):
#x1: suicidios de mujeres en mexico 2015
#x2: suicidios de hombres en mexico 2015
#n1: poblacion de mujeres
#n2: población de hombres
    dfaño = dfmexico[dfmexico["year"] == i]
    dfaux = dfpuerto[dfpuerto["year"] == i]
#    dfaño= dfaño[dfaño["sex"] == "female"]
#    dfauxm = dfauxm[dfauxm["sex"] == "female"]
    n1 = sum(dfaño["population"])
    n2 = sum(dfaux["population"])
    x1 = sum(dfaño["suicides_no"])
    x2 = sum(dfaux["suicides_no"])
    p1 = x1/n1
    p2 = x2/n2
#Prubeba de proporciones
#Estadisitoc de pruba
    p = (x1 + x2)/(n1 + n2)
#Z calculada
    z = (p1 - p2)/((p*(1 - p)*(1/n1 + 1/n2)))**.5
#La z alpa = 0.5
    if z>st.norm.ppf(.975):
        dfpaisesaux.append(np.NaN)
    elif z<-st.norm.ppf(.975):
        dfpaisesaux.append(np.NaN)
    else:
        dfpaisesaux.append(i)
dfpaises["Puerto Rico"] = dfpaisesaux

# %%
aux = []
for i in range(1985,2016):
    aux.append(i)
dfpaises["Año"] = aux
dfspain = df[df["country"] == "Spain"]
dfpaisesaux = []
for i in range(1985,2016):
#x1: suicidios de mujeres en mexico 2015
#x2: suicidios de hombres en mexico 2015
#n1: poblacion de mujeres
#n2: población de hombres
    dfaño = dfmexico[dfmexico["year"] == i]
    dfaux = dfspain[dfspain["year"] == i]
#    dfaño= dfaño[dfaño["sex"] == "female"]
#    dfauxm = dfauxm[dfauxm["sex"] == "female"]
    n1 = sum(dfaño["population"])
    n2 = sum(dfaux["population"])
    x1 = sum(dfaño["suicides_no"])
    x2 = sum(dfaux["suicides_no"])
    p1 = x1/n1
    p2 = x2/n2
#Prubeba de proporciones
#Estadisitoc de pruba
    p = (x1 + x2)/(n1 + n2)
#Z calculada
    z = (p1 - p2)/((p*(1 - p)*(1/n1 + 1/n2)))**.5
#La z alpa = 0.5
    if z>st.norm.ppf(.975):
        dfpaisesaux.append(np.NaN)
    elif z<-st.norm.ppf(.975):
        dfpaisesaux.append(np.NaN)
    else:
        dfpaisesaux.append(i)
dfpaises["España"] = dfpaisesaux

# %%
dfpaises
# Out:
#      Año  Usa  Brazil  Argentina  Chile  Puerto Rico  España
# 0   1985  NaN     NaN        NaN    NaN          NaN     NaN
# 1   1986  NaN     NaN        NaN    NaN          NaN     NaN
# 2   1987  NaN     NaN        NaN    NaN          NaN     NaN
# 3   1988  NaN     NaN        NaN    NaN          NaN     NaN
# 4   1989  NaN     NaN        NaN    NaN          NaN     NaN
# 5   1990  NaN     NaN        NaN    NaN          NaN     NaN
# 6   1991  NaN     NaN        NaN    NaN          NaN     NaN
# 7   1992  NaN     NaN        NaN    NaN          NaN     NaN
# 8   1993  NaN     NaN        NaN    NaN          NaN     NaN
# 9   1994  NaN     NaN        NaN    NaN          NaN     NaN
# 10  1995  NaN     NaN        NaN    NaN          NaN     NaN
# 11  1996  NaN     NaN        NaN    NaN          NaN     NaN
# 12  1997  NaN     NaN        NaN    NaN          NaN     NaN
# 13  1998  NaN     NaN        NaN    NaN          NaN     NaN
# ...

# %%
dfmexico
# Out:
#       country  year     sex          age  suicides_no  population  \
# 16564  Mexico  1985    male    75+ years           44      432000
# 16565  Mexico  1985    male  55-74 years          145     2330000
# 16566  Mexico  1985    male  25-34 years          340     5679000
# 16567  Mexico  1985    male  35-54 years          327     5836000
# 16568  Mexico  1985    male  15-24 years          375     8420000
# 16569  Mexico  1985  female  15-24 years          107     8211000
# 16570  Mexico  1985  female    75+ years            7      563000
# 16571  Mexico  1985  female  25-34 years           61     5661000
# 16572  Mexico  1985  female  35-54 years           55     6100000
# 16573  Mexico  1985  female  55-74 years           15     2651000
# 16574  Mexico  1985    male   5-14 years           48    11029000
# 16575  Mexico  1985  female   5-14 years           20    10654000
# 16576  Mexico  1986    male    75+ years           70      442100
# ...

# %%
dfmexicohom = dfmexico[dfmexico["sex"] == "male"]
ax = sns.boxplot(x="year", y="suicides/100k pop", data=dfmexicohom)
plt.xticks(rotation=90)
plt.title("Suicidios por cada 100")
plt.ylabel ("Suicidios por cada 100 mil mujeres")
plt.xlabel ("Año")
# Out:
# Text(0.5, 0, 'Año')

# %%
dfmexicomuj = dfmexico[dfmexico["sex"] == "female"]
ax = sns.boxplot(x="year", y="suicides/100k pop", data=dfmexicomuj)
plt.xticks(rotation=90)
plt.title("Suicidio por cada 100 mil mujeres")
plt.ylabel ("Suicidios por cada 100 mil mujeres")
plt.xlabel ("Año")
# Out:
# Text(0.5, 0, 'Año')

# %%
len(df2015m)
# Out:
# 6
